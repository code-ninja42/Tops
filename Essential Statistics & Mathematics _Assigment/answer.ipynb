# %%
import numpy as np
#que 1 
data1 = np.array([3, 2, 5, 4, 7, 2, 3, 3, 1, 6, 4, 2, 3, 5, 2, 4, 2, 1, 3, 5, 6, 3, 2, 1, 4, 2, 4, 5, 3, 2, 7, 2, 3, 4, 5, 1, 6, 2, 4, 3, 5, 3, 2, 4, 2, 6, 3, 2, 4, 5])
data1_mean = np.mean(data1)
data1_median = np.median(data1)
#mode 
data1_mean
data1_median
# Out:
# 3.0

# %%
#que 2
data1 = np.array([3, 5, 2, 4, 6, 2, 3, 4, 2, 5, 7, 2, 3, 4, 2, 4, 2, 3, 5, 6, 3, 2, 1, 4, 2, 4, 5, 3, 2, 7, 2, 3, 4, 5, 1, 6, 2, 4, 3, 5, 3, 2, 4, 2, 6, 3, 2, 4, 5, 3])
data1_range = np.max(data1) - np.min(data1)
data1_range
data1_var = np.var(data1)
data1_var
data1_std = np.std(data1)
data1_std
# Out:
# 1.513142425550219

# %%
#que 3
data1 = np.array([120,150,110,135,125,140,130,155,115,145,135,130])
data1
central_tendency = np.mean(data1)
dispersion = np.max(data1) - np.min(data1)
central_tendency
dispersion
# Out:
# 45

# %%
#que 4
A = np.array([30, 32, 33, 28, 31, 30, 29, 30, 32, 31])
B = np.array([25, 27, 26, 23, 28, 24, 26, 25, 27, 28])
C = np.array([ 22, 23, 20, 25, 21, 24, 23, 22, 25, 24])
D = np.array([18, 17, 19, 20, 21, 18, 19, 17, 20, 19])
E = np.array([ 35, 36, 34, 35, 33, 34, 32, 33, 36, 34])
mean_A = np.mean(A)
mean_B = np.mean(B)
mean_C = np.mean(C)
mean_D = np.mean(D)
mean_E = np.mean(E)
Range_A = np.max(A) - np.min(A)
Range_B = np.max(B) - np.min(B)
Range_C = np.max(C) - np.min(C)
Range_D = np.max(D) - np.min(D)
Range_E = np.max(E) - np.min(E)
Var_a = np.var(A)
Var_b = np.var(B)
Var_c = np.var(C)
Var_d = np.var(D)
Var_e = np.var(E)

# %%
#que 5 this topic is not covered

# %%
#que 6

# %%
#que 7
data = np.array([55,60,62,65,68,70,72,75,78,80,82,85,88,90,92,95,100,105,110,115,
120,125,130,135,140,145,150,155,160,165,170,175,180,185,190,195,200,205,
210,215,220,225,230,235,240,245,250,255,260,265,270,275,280,285,290,295,
300,305,310,315,320,325,330,335,340,345,350,355,360,365,370,375,380,385,
390,395,400,405,410,415,420,425,430,435,440,445,450,455,460,465,470,475,
480,485,490,495,500,505,510,515])
Q1 = np.percentile(data,25)
Q2 = np.percentile(data,50)
Q3 = np.percentile(data,75)

Per_15 = np.percentile(data,15)
per_50 = np.percentile(data, 50)
per_80 = np.percentile(data, 85)

# %%
#que 8
hours = [10,12,15,18,20,22,25,28,30,32,35,38,40,42,45,48,50,52,55,58,60,62,65,68,70,72,75,78,80,82]
scores = [60,65,70,75,80,82,85,88,90,92,93,95,96,97,98,99,100,102,105,106,107,108,110,112,114,115,116,118,120,122]
corr1 = np.corrcoef(hours,scores)[0,1]
corr1
# Out:
# 0.9772950830186736
